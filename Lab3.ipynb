# %% [markdown]
# <a href="https://colab.research.google.com/github/CristCas/Labs/blob/main/Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Программирование на языке высокого уровня (Python).
#
# https://www.yuripetrov.ru/edu/python
#
# Задание: Lab3.
#
# Выполнила: Юдаева А. В.
#
# Группа: АДЭУ-221
#
# E-mail: nastya.yudaevav@mail.ru

# %% [markdown]
# ---
#
#
# (Task 3.2.1)
#
# Составьте программу, которая запрашивает у пользователя 2 целых числа и выполняет операции:
#
# -Арифметические: +, -, * , / , // , %, **;
#
# -Сравнение: <, <=, >, >=, !=, ==,
#
# Выводя на экран результат каждого действия.
#
# В случае получение вещественного результата, округлите его до 2-х знаков после запятой (используя функцию round()).

# %%
#Task_03_02_01.

a = int(input("a="))
b = int(input('b='))

#Сумма
print(a + b) 

#Разность
print(a - b)

#Произведение
print(a * b)

#Деление с остатком (2 знака после запятой)
print(round(a / b,2))

#Деление без остатка
print(a // b)

#Остаток от деления
print(a % b)

#Возведение в степень
print(a ** b)

#Меньше
print(a <= b)

#Меньше или равно
print(a < b)

#Больше
print(a > b)

#Больше или равно
print(a >= b)

#Отрицание
print(a != b)
3
#Проверка равенства
print(a == b)

# --------------
# Пример вывода:
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# 0
# 2
# 8
# True
# True
# False
# False
# True
# False
# Out:
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# 0
# 2
# 8
# True
# True
# False
# False
# True
# False

# %% [markdown]
# ---
#
#
# (Task 3.2.2)
#
# Вычислите значение следующего выражения (аргументы - целые числа и вводятся с клавиатуры):
#
# ![12.PNG](data:image/png;base64,...)
#
# Округлите результат до 3-х знаков после запятой, используя функцию round().

# %%
#Task_03_02_02

x = int(input("x=")) #Значение x.
y = int(input("y=")) #Значение y.
z = int(input("z=")) #Значение z.

t1=x**5+7
t2=abs(-6)*y
t3=7 - (z%y)
t4=(t1/t2)**1/3
t5=t4/t3
print(round(t5,2))

res1 = ((x**5+7)/(abs(-6)*y))**(1/3)
res2 = 7 - (z%y)
res = res1/res2
print(round(res,2))

# --------------
# Пример вывода:
# x=0
# y=1
# z=2
# 0.15
# Out:
# x=0
# y=1
# z=2
# 0.06
# 0.15

# %% [markdown]
# ---
#
# (Task 3.2.3)
#
# Дана электрическая цепь, состоящая из 2-х последовательно соединенных проводников (сопротивление каждого известно).
#
# Найти общее сопротивление цепи (округление результата необходимо выполнить до 1-го знака после запятой).

# %%
#Task_03_02_03

#Сопротивление первого проводника
print('Сопротивление первого проводник?')
r1 = float(input('r1='))

#Сопротивление второго проводника
print('Сопротивление второго проводника?')
r2 = float(input('r2='))

#Общее сопротивление
r = r1 + r2
print('Общее сопротивление', round(r,1))

# --------------
# Пример вывода:
# r1=12.2
# r2=16.1
# 28.3
# Out:
# Сопротивление первого проводник?
# r1=12.2
# Сопротивление второго проводника?
# r2=16.1
# Общее сопротивление 28.3

# %% [markdown]
# ---
#
# (Task 3.2.4)
#
# Дано двузначное и трехзначное число.
#
# Для каждого выведите на экран сумму и произведение цифр.

# %%
#Task 03_02_04

#Двузначное число
num2 = list(map(int, input('Двузначное число?')))
#Трехзначное число
num3 = list(map(int, input('Трёхзначное число?')))

#1-я цифра числа 'num2'
num2_1 = num2[0]
#2-я цифра числа 'num2'
num2_2 = num2[1]

#Сумма цифр числа 'num2'
num2_s = num2_1 + num2_2
#Произведение цифр числа 'num2'
num2_p = num2_1 * num2_2

#1-я цифра числа 'num3'
num3_1 = num3[0]
#2-я цифра числа 'num3'
num3_2 = num3[1]
#3-я цифра числа 'num3'
num3_3 = num3[2]

#Сумма цифр числа 'num3'
num3_s = num3_1 + num3_2 + num3_3
#Произведение цифр числа 'num3'
num3_p = num3_1 * num3_2 * num3_3

#Вывод результата
print('Сумма и произведение первого', num2_s, num2_p)
print('Сумма и произведение второго', num3_s, num3_p)

# --------------
# Пример вывода:
# Двузначное число: 45
# Трехзначное число: 456
# Сумма и произведение цифр двузначного числа: 9 20
# Сумма и произведение цифр трехзначного числа: 15 120
# Out:
# Двузначное число?45
# Трёхзначное число?456
# Сумма и произведение первого 9 20
# Сумма и произведение второго 15 120

# %% [markdown]
# ---
#
#
# (Task 3.2.5)
#
# С начала суток прошло m минут (0<m≤24∗60). Определите:
#
# -Целое количество часов, прошедших с начала суток;
#
# -Количество минут, прошедших с момента начала последнего часа.

# %%
#Task_03_02_05

# Количество минут
m = int(input())
h = m % (24 * 60) // 60
min = m % 60

#Количество часов, прошедших с начала суток
r1 = (m - (m % 60)) // 60

print('Количество часов, прошедших с начала суток:', r1)

# --------------
# Пример вывода:
# Количество минут, прошедшее с начала суток: 123
# Количество часов, прошедших с начала суток: 2
# Количество минут, прошедших с момента начала последнего часа: 3
# Out:
# 123
# Количество часов, прошедших с начала суток: 2

# %% [markdown]
# ---
#
#
# (Task 3.2.6)
#
# Дано уравнение ax + b = 0 и отрезок [m;n].
#
# Ответьте на вопрос, попадает ли решение уравнения в указанный отрезок.

# %%
#Task_03_02_06

a = int (input('a='))
b = int (input('b='))
m = int (input('m='))
n = int (input('n='))

x = (0-b)/a

is_ok = bool((x>=m) and (x<=n))

print("Попадает:", is_ok)

# --------------
# Пример вывода:
# Введите a = 1
# Введите b = 2
# Введите m = -5
# Введите n = 5
# Попадает: True
# Out:
# a=1
# b=2
# m=-5
# n=5
# Попадает: True

# %% [markdown]
# ---
#
#
# (Task 3.2.7)
# Составьте программу, которая запрашивает название футбольной команды и повторяет его на экране со словами "Чемпион!"
#
# После этого выполните:
#
# -Используя операцию дублирования, нарисуйте черту (набор "-"), длиной, равной размеру названия команды;
#
# -Преобразуйте строку в нижний регистр и выведите на экран:
#
# -Длину наименования команды;
#
# -Есть ли в наименовании команды буква "п" (True/False)?
#
# -Сколько раз повторяется буква "а"?

# %%
team = input("Введите название команды: ")

print((team)+'-чемпион!')
print('-'*len(team))

#Название команды в нижнем регистре
team_lowercase = print(team.lower())
print('Символов в названии команды:',len(team))
print('Буква п есть:', bool('п' in 'Спартак'))
print('Количество букв а:', team.find('а'))

# --------------
# Пример вывода:
# Введите название команды: Спартак
# Спартак - чемпион!
# -------
# Символов в названии команды: 7
# Буква "п" есть: True
# Количество букв "а": 2
# Out:
# Введите название команды: Спартак
# Спартак-чемпион!
# -------
# спартак
# Символов в названии команды: 7
# Буква п есть: True
# Количество букв а: 2

# %% [markdown]
# ---
#
#
# (Task 3.2.8)
#
# Составьте программу, которая запрашивает название государства и его столицы, а затем выводит сообщение:
#
#  "Государство - ..., столица - ..."
#
# На месте многоточий должны быть выведены соответствующие значения.

# %%
#Название государства
country = input('Название государства: ')
#Название столицы
capital = input('Название столицы: ')

Co = country
Ca = capital

print('Государство -', Co, ',', 'столица -', Ca)

# --------------
# Пример вывода:
# Введите название государства: Россия
# Введите название столицы: Москва
# Государство - Россия, столица - Москва
# Out:
# Название государства: Россия
# Название столицы: Москва
# Государство - Россия , столица - Москва

# %% [markdown]
# ---
#
#
# (Task 3.2.9)
#
# Дано слово объектно-ориентированный.
#
# Используя индексацию и срезы составьте из него слова объект, ориентир, тир, кот, рента и выведите их на экран.

# %%
#Task 03.02.09

word = "объектно-ориентированный"
#Объект
w1 = word[:6]
#Ориентир
w2 = word[9:17]
#Тир
w3 = word[5] + word[11] + word[10]
#Кот
w4 = word[4] + word[0] + word[5]
#Рента
w5 = word[10] + word[3] + word[6] + word[5] + word[19]

print(w1, w2, w3, w4, w5, sep="\n")

# --------------
# Пример вывода:
# объект
# ориентир
# тир
# кот
# рента
# Out:
# объект
# ориентир
# тир
# кот
# рента
